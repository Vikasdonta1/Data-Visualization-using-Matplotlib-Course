# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikasdonta1/Data-Visualization-using-Matplotlib-Course/blob/main/Quandl_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Quandl API to Plot Real Time Stock Data**
# https://www.quandl.com/
#
# The premier source for financial, economic and alternative datasets, serving investment professionals.

# %%
pip install quandl

# %%
import quandl
data = quandl.get("BSE/BOM539678", authtoken="x8VdDXzBty3iGsaRLTVs")
data
# Out:
#               Open    High     Low   Close     WAP  No. of Shares  \
# Date
# 2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
# 2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# ...            ...     ...     ...     ...     ...            ...
# 2022-09-19  200.50  202.50  194.85  196.60  199.20        12643.0
# 2022-09-20  199.30  199.65  193.00  195.60  197.67         6286.0
# 2022-09-21  196.05  196.05  191.70  192.30  194.12         8807.0
# 2022-09-22  190.00  194.35  190.00  193.45  192.79        11676.0
# 2022-09-23  193.00  194.55  191.00  192.65  192.94        22816.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2017-02-21         1048.0      10426526.0                9129.0
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('figure',figsize=(18,5))

plt.plot(data.Open)

plt.savefig('stock.pdf')
plt.savefig('stock.png')
plt.show()

# %% [markdown]
# **Plot using JSON**

# %%
import requests
r = requests.get('https://www.quandl.com/api/v3/datasets/BSE/BOM539678.json?api_key=x8VdDXzBty3iGsaRLTVs')
r
# Out:
# <Response [200]>

# %%
import json
data = json.loads(r.content)
data

# %%
import pandas as pd
df = pd.DataFrame(data['dataset']['data'],columns=data['dataset']['column_names'])
df
# Out:
#             Date    Open    High     Low   Close     WAP  No. of Shares  \
# 0     2022-09-23  193.00  194.55  191.00  192.65  192.94        22816.0
# 1     2022-09-22  190.00  194.35  190.00  193.45  192.79        11676.0
# 2     2022-09-21  196.05  196.05  191.70  192.30  194.12         8807.0
# 3     2022-09-20  199.30  199.65  193.00  195.60  197.67         6286.0
# 4     2022-09-19  200.50  202.50  194.85  196.60  199.20        12643.0
# ...          ...     ...     ...     ...     ...     ...            ...
# 1380  2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# 1381  2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 1382  2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 1383  2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 1384  2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
#
#       No. of Trades  Total Turnover  Deliverable Quantity  \
# ...

# %%
df.set_index('Date',inplace=True)

# %%
df = df.sort_index()
df
# Out:
#               Open    High     Low   Close     WAP  No. of Shares  \
# Date
# 2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
# 2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# ...            ...     ...     ...     ...     ...            ...
# 2022-09-19  200.50  202.50  194.85  196.60  199.20        12643.0
# 2022-09-20  199.30  199.65  193.00  195.60  197.67         6286.0
# 2022-09-21  196.05  196.05  191.70  192.30  194.12         8807.0
# 2022-09-22  190.00  194.35  190.00  193.45  192.79        11676.0
# 2022-09-23  193.00  194.55  191.00  192.65  192.94        22816.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2017-02-21         1048.0      10426526.0                9129.0
# ...

# %%
df.index = pd.to_datetime(df.index, dayfirst=True)

# %%
import matplotlib.pyplot as plt

plt.rc('figure',figsize=(18,5))

plt.plot(df.Open)

plt.savefig('stock.pdf')
plt.savefig('stock.png')
plt.show()
